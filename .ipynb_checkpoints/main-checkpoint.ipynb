# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'Dataset .csv')
df.sample(8)
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 9434       18261203  Sabai Thai - The Westin Doha Hotel & Spa           166
# 7149       18481404                                Dosa Plaza             1
# 2661       18350112                 Target Ice Cream & Bakers             1
# 579         5702615                                 Via Delhi           214
# 2548        1600053                          Enter The Dragon             1
# 7470           3239                    Insomnia - Taj Vivanta             1
# 5046           4315                        The Tandoori Night             1
# 9181        2700002           Moti Mahal Delux Tandoori Trail             1
#
#            City                                            Address  \
# 9434       Doha  Ground Floor, The Westin Doha Hotel & Spa, Fer...
# 7149  New Delhi  B-165, 1st Floor, Main Market Bhajanpura, Shah...
# 2661  New Delhi  Ground Floor, 4, Vigyan Vihar, Anand Vihar, Ne...
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# ## handling null value

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df['Cuisines'].isna().sum()
# Out:
# 9

# %%
df[df['Cuisines'].isna()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
df['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
df.dropna(inplace= True, axis= 0)

# %%
df[df['Cuisines'].isna()]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df['Country Code'].value_counts()
# Out:
# Country Code
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
df['Address'].value_counts()
# Out:
# Address
# Dilli Haat, INA, New Delhi                                                   11
# Sector 41, Noida                                                             11
# Greater Kailash (GK) 1, New Delhi                                            10
# The Imperial, Janpath, New Delhi                                              9
# Cyber Hub, DLF Cyber City, Gurgaon                                            8
#                                                                              ..
# 108 & 126, Flyover Market, Defence Colony, New Delhi                          1
# Shop 25,27 & 29, Defence Colony Flyover Market, Defence Colony, New Delhi     1
# D  Block, Defence Colony, New Delhi                                           1
# A-1, Defence Colony, New Delhi                                                1
# Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, Kad۱k�_y, ��stanbul             1
# Name: count, Length: 8910, dtype: int64

# %%
df['Restaurant Name'].value_counts().head(10)
# Out:
# Restaurant Name
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
# Keventers           34
# Pizza Hut           30
# Giani               29
# Baskin Robbins      28
# Barbeque Nation     26
# Name: count, dtype: int64

# %%
df.sample(11)
# Out:
#       Restaurant ID                   Restaurant Name  Country Code  \
# 7414       18430905        Ram Ram Ji Kachori Bhandar             1
# 2281       18384506                The Basement Caf��             1
# 6187           9956                        McDonald's             1
# 7180       18180080                       Greenr Cafe             1
# 5769         305859                          Frontier             1
# 1941       18279913             Tasha's Artisan Foods             1
# 497        17099925                  Red Mesa Cantina           216
# 1252         308022                        Farzi Cafe             1
# 2746       18057820  Puran Chand Ambala Wale Di Hatti             1
# 6518       18461352                Rupa Bangali Dhaba             1
# 7990       18446483                           Karim's             1
#
#            City                                            Address  \
# 7414  New Delhi  WZ 10, Tihar Village, Main Road, Subhash Nagar...
# ...

# %%
df['City'].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: count, Length: 140, dtype: int64

# %%
df['Locality'].value_counts()
# Out:
# Locality
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Pitampura                                       85
#                                               ...
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Ramada Gurgaon Central, Sector 44                1
# Moda                                             1
# Name: count, Length: 1206, dtype: int64

# %%
df['Locality Verbose'].value_counts()
# Out:
# Locality Verbose
# Connaught Place, New Delhi                    122
# Rajouri Garden, New Delhi                      99
# Shahdara, New Delhi                            87
# Defence Colony, New Delhi                      86
# Pitampura, New Delhi                           85
#                                              ...
# Ramada Gurgaon Central, Sector 44, Gurgaon      1
# Sector 5, Gurgaon                               1
# Sector 53, Gurgaon                              1
# The Claremont, MG Road, Gurgaon                 1
# Moda, ��stanbul                                 1
# Name: count, Length: 1263, dtype: int64

# %%
df['Latitude'].value_counts()
# Out:
# Latitude
# 0.000000     498
# 28.574309     16
# 28.551456      9
# 28.574300      9
# 28.597103      8
#             ...
# 28.641341      1
# 28.644472      1
# 28.648229      1
# 28.644812      1
# 40.984776      1
# Name: count, Length: 8668, dtype: int64

# %%
df['Longitude'].value_counts()
# Out:
# Longitude
# 0.000000     498
# 77.353663     19
# 77.230412     12
# 77.088688     10
# 77.251426      9
#             ...
# 77.134037      1
# 77.228705      1
# 77.230456      1
# 77.229064      1
# 29.026016      1
# Name: count, Length: 8111, dtype: int64

# %%
df['Average Cost for two'].value_counts()
# Out:
# Average Cost for two
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 8000        1
# 2350        1
# 150000      1
# 70000       1
# 545         1
# Name: count, Length: 140, dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
df.sample(10)
# Out:
#       Restaurant ID              Restaurant Name  Country Code       City  \
# 8817       18435805    South Indian Snacks Stall             1      Noida
# 8810       18157407                 Taste In Box             1      Noida
# 348        16613059                   Poets Cafe            14  Montville
# 2745       18449782                Hunger Flames             1  New Delhi
# 2235       18350125                   Nukkadwala             1    Gurgaon
# 320        17452342  Blue Orchid Thai Restaurant           216    Lincoln
# 8975       18418250              Zooby's Kitchen             1      Noida
# 6287         300872                Bansal Sweets             1  New Delhi
# 3372         302497             Mathur's Kitchen             1  New Delhi
# 5831           5537            New Vishal Corner             1  New Delhi
#
#                                                 Address  \
# 8817                            E-4/7, Sector 56, Noida
# ...

# %%
df['Aggregate rating'].value_counts()
# Out:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     495
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     399
# 2.9     381
# 3.9     332
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     143
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      41
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
df.drop(['Restaurant ID', 'Locality Verbose'], axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#                   Restaurant Name  Country Code       City  \
# 6731                          KFC             1  New Delhi
# 2287        The Zouq : Resto-Cafe             1   Guwahati
# 2952              Brownies & More             1  New Delhi
# 6835                 Home Kitchen             1  New Delhi
# 320   Blue Orchid Thai Restaurant           216    Lincoln
# 4063                   Daya Sagar             1  New Delhi
# 7102                       Empire             1  New Delhi
# 293               Bespoke Harvest            14    Forrest
# 1130               Domino's Pizza             1  Ghaziabad
# 4756            Jeeta Kulfi Walle             1  New Delhi
#
#                                                 Address  \
# 6731  G-1-8, Ground Floor, NN Mall,Near M2K Cinemas,...
# 2287  1st Floor, Royal Orchard, House 1, By Lane 2, ...
# 2952         32, Market 4, Chittaranjan Park, New Delhi
# 6835  Humanyupur, Safdarjung Enclave, Safdarjung, Ne...
# ...

# %%
df.describe()
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9542.000000  9542.000000  9542.000000           9542.000000
# mean      18.179208    64.274997    25.848532           1200.326137
# std       56.451600    41.197602    11.010094          16128.743876
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081565    28.478658            250.000000
# 50%        1.000000    77.192031    28.570444            400.000000
# 75%        1.000000    77.282043    28.642711            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9542.000000       9542.000000   9542.000000
# mean      1.804968          2.665238    156.772060
# std       0.905563          1.516588    430.203324
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# ...

# %%
country_counts = df['Country Code'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values)
plt.xlabel('Country Code')
plt.ylabel('Count')
plt.title('Distribution of Country Codes')
plt.show()

# %%
city_counts = df['City'].value_counts().head(10)  # Selecting top 10 cities
plt.figure(figsize=(12, 6))
sns.barplot(x=city_counts.index, y=city_counts.values)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Top 10 Cities with Highest Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %%
top_cuisines = df['Cuisines'].value_counts().head(10)  # Selecting top 10 cuisines
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cuisines.index, y=top_cuisines.values)
plt.xlabel('Cuisine')
plt.ylabel('Count')
plt.title('Top 10 Cuisines')
plt.xticks(rotation=45)
plt.show()

# %%
cuisine_counts = df['Cuisines'].value_counts()
top_cuisines = cuisine_counts.nlargest(10)
city_counts = df['City'].value_counts()
top_cities = city_counts.nlargest(10)
print("Top Cuisines:")
print(top_cuisines)
# Out:
# Top Cuisines:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
city_counts = df['City'].value_counts()
country_counts = df['Country Code'].value_counts()

# Plotting the distribution of restaurants across cities
plt.figure(figsize=(12, 6))
sns.barplot(x=city_counts.index[:10], y=city_counts.values[:10])
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.title('Top 10 Cities with the Highest Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# Plotting the distribution of restaurants across countries
plt.figure(figsize=(12, 6))
sns.barplot(x=country_counts.index[:10], y=country_counts.values[:10])
plt.xlabel('Country Code')
plt.ylabel('Number of Restaurants')
plt.title('Top 10 Countries with the Highest Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# Correlation between Location and Rating
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Longitude', y='Latitude', hue='Aggregate rating', data=df, palette='Set1')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Restaurant Locations with Ratings')
plt.show()

# Correlation between Aggregate rating and other numerical variables
correlation_matrix = df[['Longitude', 'Latitude', 'Aggregate rating', 'Average Cost for two', 'Price range', 'Votes']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Address', 'Locality',
#        'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
df['Has Table booking'] = df['Has Table booking'].map({'Yes': 1, 'No': 0})
df['Has Online delivery'] = df['Has Online delivery'].map({'Yes': 1, 'No': 0})

# Determine the percentage of restaurants that offer table booking and online delivery
table_booking_percentage = (df['Has Table booking'].sum() / len(df)) * 100
online_delivery_percentage = (df['Has Online delivery'].sum() / len(df)) * 100

print("Percentage of Restaurants Offering Table Booking: {:.2f}%".format(table_booking_percentage))
print("Percentage of Restaurants Offering Online Delivery: {:.2f}%".format(online_delivery_percentage))
# Out:
# Percentage of Restaurants Offering Table Booking: 12.14%
# Percentage of Restaurants Offering Online Delivery: 25.69%

# %%
average_rating_with_booking = df[df['Has Table booking'] == 1]['Aggregate rating'].mean()
average_rating_without_booking = df[df['Has Table booking'] == 0]['Aggregate rating'].mean()

print("Average Rating of Restaurants with Table Booking: {:.2f}".format(average_rating_with_booking))
print("Average Rating of Restaurants without Table Booking: {:.2f}".format(average_rating_without_booking))

# Analyze the availability of online delivery among restaurants with different price ranges
plt.figure(figsize=(10, 6))
sns.boxplot(x='Price range', y='Has Online delivery', data=df)
plt.xlabel('Price Range')
plt.ylabel('Has Online Delivery')
plt.title('Availability of Online Delivery among Different Price Ranges')
plt.show()
# Out:
# Average Rating of Restaurants with Table Booking: 3.44
# Average Rating of Restaurants without Table Booking: 2.56

# %%
df
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546               Naml۱ Gurme           208         ��stanbul
# 9547              Ceviz A��ac۱           208         ��stanbul
# 9548                     Huqqa           208         ��stanbul
# 9549               A���k Kahve           208         ��stanbul
# 9550  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# ...

# %%
df['Is delivering now'] = df['Is delivering now'].map({'Yes': 1, 'No': 0})
df['Switch to order menu'] = df['Switch to order menu'].map({'Yes': 1, 'No': 0})
df.sample()
# Out:
#      Restaurant Name  Country Code       City  \
# 4413   Komal Kitchen             1  New Delhi
#
#                                     Address Locality  Longitude   Latitude  \
# 4413  J-4/1A, DDA Flats, Kalkaji, New Delhi  Kalkaji  77.256081  28.528272
#
#           Cuisines  Average Cost for two            Currency  \
# 4413  North Indian                   250  Indian Rupees(Rs.)
#
#       Has Table booking  Has Online delivery  Is delivering now  \
# 4413                  0                    0                  0
#
#       Switch to order menu  Price range  Aggregate rating Rating color  \
# 4413                     0            1               2.8       Orange
#
#      Rating text  Votes
# 4413     Average      7

# %%
most_common_price_range = df['Price range'].mode()[0]
print("Most Common Price Range among all the restaurants:", most_common_price_range)

# Task 2: Calculate the average rating for each price range
average_rating_by_price_range = df.groupby('Price range')['Aggregate rating'].mean()
print("\nAverage Rating for Each Price Range:")
print(average_rating_by_price_range)

# Task 3: Identify the color that represents the highest average rating among different price ranges
highest_avg_rating_color = df[df.groupby('Price range')['Aggregate rating'].transform('max') == df['Aggregate rating']]['Rating color'].mode()[0]
print("\nColor representing the highest average rating among different price ranges:", highest_avg_rating_color)
# Out:
# Most Common Price Range among all the restaurants: 1
#
# Average Rating for Each Price Range:
# Price range
# 1    1.997476
# 2    2.941054
# 3    3.682633
# 4    3.817918
# Name: Aggregate rating, dtype: float64
#
# Color representing the highest average rating among different price ranges: Dark Green

# %%
df.sample()
# Out:
#      Restaurant Name  Country Code   City  \
# 8384         Barista             1  Noida
#
#                                           Address   Locality  Longitude  \
# 8384  A 5, Ground Floor, Atrium, Sector 16, Noida  Sector 16   77.31561
#
#        Latitude Cuisines  Average Cost for two            Currency  \
# 8384  28.579317     Cafe                   650  Indian Rupees(Rs.)
#
#       Has Table booking  Has Online delivery  Is delivering now  \
# 8384                  0                    0                  0
#
#       Switch to order menu  Price range  Aggregate rating Rating color  \
# 8384                     0            2               2.9       Orange
#
#      Rating text  Votes
# 8384     Average     22

# %%
length_of_ResName = []
length_of_address = []

def lenfind(x):
    for i in x:
        leng = len(i)
        length_of_ResName.append(leng)

def lenfind2(x):
    for i in x:
        leng = len(i)
        length_of_address.append(leng)
        
lenfind(df['Restaurant Name'])
lenfind2(df['Address'])

# %%
df['Restaurent name Length'] = length_of_ResName
df['Restaurent address length'] = length_of_address

# %%
df.sample()
# Out:
#      Restaurant Name  Country Code     City  \
# 1240         Smaaash             1  Gurgaon
#
#                                  Address                   Locality  \
# 1240  Cyber Hub, DLF Cyber City, Gurgaon  Cyber Hub, DLF Cyber City
#
#       Longitude   Latitude                         Cuisines  \
# 1240  77.088913  28.495005  North Indian, Thai, Continental
#
#       Average Cost for two            Currency  Has Table booking  \
# 1240                  1400  Indian Rupees(Rs.)                  0
#
#       Has Online delivery  Is delivering now  Switch to order menu  \
# 1240                    0                  0                     0
#
#       Price range  Aggregate rating Rating color Rating text  Votes  \
# 1240            3               3.9       Yellow        Good    622
#
#       Restaurent name Length  Restaurent address length
# 1240                       7                         34

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df.drop(['Restaurant Name', 'Address', 'Locality', 'Rating text'], axis=1, inplace= True)
df.sample()
# Out:
#      Country Code        City  Longitude  Latitude          Cuisines  \
# 716             1  Aurangabad        0.0       0.0  Juices, Desserts
#
#      Average Cost for two            Currency  Has Table booking  \
# 716                   300  Indian Rupees(Rs.)                  0
#
#      Has Online delivery  Is delivering now  Switch to order menu  \
# 716                    0                  0                     0
#
#      Price range  Aggregate rating Rating color  Votes  \
# 716            1               3.5       Yellow     21
#
#      Restaurent name Length  Restaurent address length
# 716                      19                         69

# %%
df['Rating color'].value_counts()
# Out:
# Rating color
# Orange        3734
# White         2148
# Yellow        2096
# Green         1078
# Dark Green     300
# Red            186
# Name: count, dtype: int64

# %%
df['Rating color'] = df['Rating color'].replace({
    'White': 0,
    'Dark Green': 5,
    'Green': 4,
    'Yellow': 3,
    'Orange': 2,
    'Red': 1
})
df.sample()
# Out:
#      Country Code    City  Longitude   Latitude Cuisines  \
# 217           216  Dalton -84.999678  34.758645  Italian
#
#      Average Cost for two   Currency  Has Table booking  Has Online delivery  \
# 217                    25  Dollar($)                  0                    0
#
#      Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 217                  0                     0            2               3.7
#
#      Rating color  Votes  Restaurent name Length  Restaurent address length
# 217             3    116                      33                         31

# %%
df['Currency'].value_counts()
# Out:
# Currency
# Indian Rupees(Rs.)        8652
# Dollar($)                  473
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Currency'] = encoder.fit_transform(df['Currency'])
df.sample()
# Out:
#       Country Code     City  Longitude   Latitude           Cuisines  \
# 1704             1  Gurgaon  77.102546  28.472118  Bakery, Beverages
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 1704                   500         4                  0                    0
#
#       Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 1704                  0                     0            2               3.4
#
#       Rating color  Votes  Restaurent name Length  Restaurent address length
# 1704             2     57                      20                         33

# %%
df['Cuisines'] = encoder.fit_transform(df['Cuisines'])
df.sample()
# Out:
#       Country Code       City  Longitude   Latitude  Cuisines  \
# 7421             1  New Delhi  77.112245  28.636897       201
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 7421                   200         4                  0                    1
#
#       Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 7421                  0                     0            1               0.0
#
#       Rating color  Votes  Restaurent name Length  Restaurent address length
# 7421             0      2                      20                         30

# %%
df['City'] = encoder.fit_transform(df['City'])
df.sample()
# Out:
#      Country Code  City  Longitude   Latitude  Cuisines  Average Cost for two  \
# 817             1    26  80.254791  13.027018       800                  1200
#
#      Currency  Has Table booking  Has Online delivery  Is delivering now  \
# 817         4                  1                    1                  0
#
#      Switch to order menu  Price range  Aggregate rating  Rating color  Votes  \
# 817                     0            3               4.3             4   1607
#
#      Restaurent name Length  Restaurent address length
# 817                      10                         36

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
lr = LinearRegression()

# %%
X = df.drop('Aggregate rating', axis= 1)
y = df['Aggregate rating']

# %%
X = scaler.fit_transform(X)
X
# Out:
# array([[ 2.54781671, -0.20063686,  1.37764114, ...,  0.36549271,
#          0.12209747,  1.01907594],
#        [ 2.54781671, -0.20063686,  1.37731503, ...,  1.00940804,
#          0.12209747,  0.78543492],
#        [ 2.54781671, -0.11284098,  1.37835228, ...,  0.26321013,
#          0.99698162,  0.1429221 ],
#        ...,
#        [ 3.36271675,  2.69662705, -0.85544309, ...,  1.17213033,
#         -1.4818568 ,  1.13589646],
#        [ 3.36271675,  2.69662705, -0.85540962, ...,  1.73003531,
#         -0.60697265,  1.25271697],
#        [ 3.36271675,  2.69662705, -0.85565243, ...,  1.00940804,
#          1.28860967,  0.66861441]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=37, shuffle=True,)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([0.53556988, 2.6791998 , 2.61859086, ..., 0.38113955, 2.68841606,
#        3.83925014])

# %%
from sklearn.metrics import r2_score

r_squared = r2_score(y_test, y_pred)
print(f'Accuracy is: {100 * r_squared.round(2)}%')
# Out:
# Accuracy is: 91.0%

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Aggregate rating'], bins=20, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# Comparison of Average Ratings by Cuisine
# avg_ratings_by_cuisine = data.groupby('Cuisine')['Rating'].mean().sort_values(ascending=False).head(10)
# plt.figure(figsize=(12, 6))
# avg_ratings_by_cuisine.plot(kind='bar', color='skyblue')
# plt.title('Average Ratings by Cuisine')
# plt.xlabel('Cuisine')
# plt.ylabel('Average Rating')
# plt.xticks(rotation=45)
# plt.show()

# Comparison of Average Ratings by City
avg_ratings_by_city = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
avg_ratings_by_city.plot(kind='bar', color='salmon')
plt.title('Average Ratings by City')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# Visualizing Relationship between Features and Target Variable
# Scatter plot of 'Average Cost for two' vs. 'Rating'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Average Cost for two', y='Aggregate rating', data=df)
plt.title('Average Cost for Two vs. Rating')
plt.xlabel('Average Cost for Two')
plt.ylabel('Rating')
plt.show()

# Box plot of 'Has Table Booking' vs. 'Rating'
plt.figure(figsize=(8, 6))
sns.boxplot(x='Has Table booking', y='Aggregate rating', data=df)
plt.title('Has Table Booking vs. Rating')
plt.xlabel('Has Table Booking')
plt.ylabel('Rating')
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
